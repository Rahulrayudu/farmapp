# %% [markdown]
# 20BPS1099 JALADI DEEPIKA
# AI ASSIGNMENT 1

# %% [markdown]
# Task 1:Create pandas dataframe(Dataframe name 'df')with numpy random values(4 feautures and 4 observations)

# %%
import pandas as pd
import numpy as np

# %%
# Creating 4 series

s1 = pd.Series(np.random.rand(4))
s2 = pd.Series(np.random.rand(4))
s3 = pd.Series(np.random.rand(4))
s4 = pd.Series(np.random.rand(4))


print(s1,s2,s3,s4)
# Out:
# 0    0.348232
# 1    0.489378
# 2    0.579000
# 3    0.455505
# dtype: float64 0    0.307218
# 1    0.526133
# 2    0.562602
# 3    0.123695
# dtype: float64 0    0.934625
# 1    0.920256
# 2    0.386629
# 3    0.450173
# dtype: float64 0    0.758984
# 1    0.689777
# 2    0.898528
# 3    0.445713
# dtype: float64

# %%
# Creating dataframe df with the series

df = pd.DataFrame([s1,s2,s3,s4])
df
# Out:
#           0         1         2         3
# 0  0.348232  0.489378  0.579000  0.455505
# 1  0.307218  0.526133  0.562602  0.123695
# 2  0.934625  0.920256  0.386629  0.450173
# 3  0.758984  0.689777  0.898528  0.445713

# %% [markdown]
#  Task 2: Rename the task 1 Dataframe df Column names To Random value 1,Random value 2,Random value 3,Random value 4

# %%
# Changing the column name

df.columns = ['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.348232        0.489378        0.579000        0.455505
# 1        0.307218        0.526133        0.562602        0.123695
# 2        0.934625        0.920256        0.386629        0.450173
# 3        0.758984        0.689777        0.898528        0.445713

# %% [markdown]
# Task 3: Find the descriptive statastics of the 'df' dataframe

# %%
#descriptive statastics
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.587265        0.656386        0.606690        0.368772
# std          0.308604        0.196299        0.213156        0.163433
# min          0.307218        0.489378        0.386629        0.123695
# 25%          0.337979        0.516944        0.518609        0.365208
# 50%          0.553608        0.607955        0.570801        0.447943
# 75%          0.802894        0.747397        0.658882        0.451506
# max          0.934625        0.920256        0.898528        0.455505

# %% [markdown]
# Task 4:Check for the null values in 'df' and find the datatype of each column

# %%
# Finding null values

df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
# Checking the datatype for 'Random value 1'
df['Random value 1'].dtype
# Out:
# dtype('float64')

# %%
# Checking the datatype for Random value 2

df['Random value 2'].dtype
# Out:
# dtype('float64')

# %%
# Checking the datatype for Random value 3

df['Random value 3'].dtype
# Out:
# dtype('float64')

# %%
# Checking the datatype for Random value 4

df['Random value 4'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Task 5: Display Random value 2 and Random value 3 columns with location and index location methods

# %%
#location method
# give the actual row and column name as a parameter

df.loc[0:3,'Random value 2':'Random value 3']
# Out:
#    Random value 2  Random value 3
# 0        0.489378        0.579000
# 1        0.526133        0.562602
# 2        0.920256        0.386629
# 3        0.689777        0.898528

# %%
#index location method
# give the actual row and column index value as a parameter

df.iloc[0:,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.489378        0.579000
# 1        0.526133        0.562602
# 2        0.920256        0.386629
# 3        0.689777        0.898528
